# %%
class Student:
    school = "UniMAP"

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def enrolment(self, course):
        self.course = course
        return f"Name: {self.name} | Age: {self.age}! | Course: {self.course}"


student = Student("Zaim", 25)

student.enrolment("SCCE")
# Out:
# 'Name: Zaim | Age: 25! | Course: SCCE'
